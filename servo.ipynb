# %% [markdown]
# <a href="https://colab.research.google.com/github/nandhini2113/CODSOFT/blob/main/servo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Servo Mechanism.csv")
df
# Out:
#     Motor Screw  Pgain  Vgain  Class
# 0       E     E      5      4      4
# 1       B     D      6      5     11
# 2       D     D      4      3      6
# 3       B     A      3      2     48
# 4       D     B      6      5      6
# ..    ...   ...    ...    ...    ...
# 162     B     C      3      2     44
# 163     B     E      3      1     40
# 164     C     D      4      3     25
# 165     A     B      3      2     44
# 166     A     A      6      5     20
#
# [167 rows x 5 columns]

# %%
df.head()
# Out:
#   Motor Screw  Pgain  Vgain  Class
# 0     E     E      5      4      4
# 1     B     D      6      5     11
# 2     D     D      4      3      6
# 3     B     A      3      2     48
# 4     D     B      6      5      6

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# ...                                                 ...
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [4898 rows x 1 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Motor   167 non-null    object
#  1   Screw   167 non-null    object
#  2   Pgain   167 non-null    int64
#  3   Vgain   167 non-null    int64
#  4   Class   167 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 6.6+ KB

# %%
df.columns
# Out:
# Index(['Motor', 'Screw', 'Pgain', 'Vgain', 'Class'], dtype='object')

# %%
df.shape
# Out:
# (167, 5)

# %%
df.describe()
# Out:
#             Pgain       Vgain       Class
# count  167.000000  167.000000  167.000000
# mean     4.155689    2.538922   21.173653
# std      1.017770    1.369850   13.908038
# min      3.000000    1.000000    1.000000
# 25%      3.000000    1.000000   10.500000
# 50%      4.000000    2.000000   18.000000
# 75%      5.000000    4.000000   33.500000
# max      6.000000    5.000000   51.000000

# %%
df.isna().sum()
# Out:
# Motor    0
# Screw    0
# Pgain    0
# Vgain    0
# Class    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Motor'] = le.fit_transform(df['Motor'])
df['Screw'] = le.fit_transform(df['Screw'])
df
# Out:
#      Motor  Screw  Pgain  Vgain  Class
# 0        4      4      5      4      4
# 1        1      3      6      5     11
# 2        3      3      4      3      6
# 3        1      0      3      2     48
# 4        3      1      6      5      6
# ..     ...    ...    ...    ...    ...
# 162      1      2      3      2     44
# 163      1      4      3      1     40
# 164      2      3      4      3     25
# 165      0      1      3      2     44
# 166      0      0      6      5     20
#
# [167 rows x 5 columns]

# %%
x = df.drop('Class',axis=1)

# %%
y = df['Class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
mdl = lr.fit(x_train,y_train)
mdl
# Out:
# LinearRegression()

# %%
pre = mdl.predict(x_test)
pre
# Out:
# array([ 7.98763908, 16.98699882, 26.36587342, 25.43994284, 16.21804252,
#        12.70561842, 11.13977571, 20.85535904, 14.453238  ,  3.04711917,
#        36.43739285, 18.54849016, -7.02440026, 20.16706557, 26.64549806,
#        23.90203025,  9.73525867, 17.06331028, -4.41867935, 29.74490199,
#        36.85041303, 32.1324337 , 22.41685037, 13.83051082, 35.23183762,
#        21.78128962, 21.21129515,  8.52970344, 36.76975021, 17.42359775,
#        36.08145674, 16.62671135, 30.59452111, 16.29435399, 15.44908623,
#        24.3913619 , 12.34533094, 30.51385828, -1.67521153, 18.19255405,
#        18.96151034, 18.68188569])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print(mean_absolute_error(y_test,pre))
print(mean_squared_error(y_test,pre))
# Out:
# 7.088206857654151
# 66.00271453939651
